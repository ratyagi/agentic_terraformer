# %%
# you will require your GitHub Token
from getpass import getpass
token = getpass('Enter your GitHub token: ')
# !git clone https://{token}@github.com/ratyagi/agentic_terraformer
# Out:
# Enter your GitHub token: ··········
# Cloning into 'agentic_terraformer'...
# remote: Enumerating objects: 239, done.
# remote: Counting objects: 100% (239/239), done.
# remote: Compressing objects: 100% (209/209), done.
# remote: Total 239 (delta 105), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (239/239), 85.54 KiB | 2.95 MiB/s, done.
# Resolving deltas: 100% (105/105), done.

# %%
# %cd /content/agentic_terraformer
# Out:
# /content/agentic_terraformer

# %%
# Install all project dependencies
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 83.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 116.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from core.config import setup_logging
from main import run_session, print_report

setup_logging()

goal_text = (
    "Design a 10-year plan to reduce CO2 emissions by 40% in coastal_city_01 "
    "with minimal job loss."
)

session_id = run_session(goal_text, region_id="coastal_city_01")
print("Session ID:", session_id)
print_report(session_id)
# Out:
# ERROR:tools.climate_data_tool:Region 'coastal_city_01' not found. Available:
# ERROR:core.message_bus:Error handling message POLICY by agent DataAgent: "Region 'coastal_city_01' not found. Available: "
# Traceback (most recent call last):
#   File "/content/agentic_terraformer/core/message_bus.py", line 104, in run
#     agent.handle_message(msg, self)  # type: ignore[attr-defined]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/agentic_terraformer/agents/data_agent.py", line 30, in handle_message
#     region_data = load_region(region_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/agentic_terraformer/tools/climate_data_tool.py", line 116, in load_region
#     raise KeyError(msg)
# KeyError: "Region 'coastal_city_01' not found. Available: "
# WARNING:tools.storage_tool:Report not found for session 584b02ae-de01-497f-8388-777914bf7a95
# Session ID: 584b02ae-de01-497f-8388-777914bf7a95
# No report found for session 584b02ae-de01-497f-8388-777914bf7a95
